# %%
import pandas as pd
from pathlib import Path
import os

# %%
from ETLCodeBase.gold._helpers import classify_pillar, standardize_product
from ETLCodeBase.gold.user_inputs import process_units
from ETLCodeBase.gold.finance_logic import process_finance

# %%
base = Path("c:/Users/ZheRao/OneDrive - Monette Farms/Monette Farms Team Site - Innovation Projects/Production/Database")

# %%
gold_path = base / "Gold" / "FinanceOperationalProject"
payroll_path = base / Path("Gold/HRProject/PayrollProject")
silver_acc_path = base / Path("Silver/QBO/Dimension/CSV")
os.listdir(gold_path)
# Out:
# ['AccNumTOAccID.csv',
#  'Account_table.csv',
#  'Account_table.xlsx',
#  'allocation_schedule.csv',
#  'ManualAdjustments',
#  'old',
#  'PL.csv',
#  'PL.xlsx',
#  'PL2.xlsx',
#  'ProfitTypeSummary.csv',
#  'ProfitTypeSummary.xlsx',
#  'ProfitTypeSummary2.xlsx']

# %%
df = process_finance()
df
# Out:
# Starting Finance Operational Project Transformation
#
# Revising Signs ...
# Saving ...
#        TransactionDate TransactionType TransactionID_partial    DocNumber  \
# 0           2025-10-01   Journal Entry            MFUSA17180  MFUSA-1970R
# 1           2025-10-01   Journal Entry            MFUSA17180  MFUSA-1970R
# 2           2025-10-01   Journal Entry            MFUSA17180  MFUSA-1970R
# 3           2025-10-31   Journal Entry            MFUSA17181   MFUSA-2073
# 4           2025-10-31   Journal Entry            MFUSA17181   MFUSA-2073
# ...                ...             ...                   ...          ...
# 216430      2024-07-31   Journal Entry              MFL70878     MFL-5584
# 216431      2024-08-01   Journal Entry              MFL78125    MFL-5584R
# 216432      2024-07-31   Journal Entry              MFL70878     MFL-5584
# 216433      2024-08-01   Journal Entry              MFL78125    MFL-5584R
# ...
